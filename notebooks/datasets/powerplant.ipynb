# %%
import numpy as np
import numpy.random as npr
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler

from src.utils import util, data_loaders
from src.utils.domain_split import hyperplane_split
from src.model import MLP
from src.train_test import fit_regr, test_regr

seed = npr.randint(10000)
# seed = 9871
np.random.seed(seed)
torch.manual_seed(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
df = pd.read_csv("../../data/regression/powerplant.csv")
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
D = df.values
dom_idx, OOD_idx = hyperplane_split(D, OOD_size=0.2, verbose=1, seed=seed)
df[dom_idx].head()
# Out:
# Found random direction n = [-6.68669495e-04  3.37206765e-01 -5.35696470e-01 -7.64690266e-01
#   1.20703107e-01]
# Found split with ratio r = 0.20066889632107024
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 6  22.10  71.29  1008.20  75.38  442.35

# %%
# Minmax scaling for better network performace
scaler = MinMaxScaler()
D = df[dom_idx].values
D = scaler.fit_transform(D)

# Split in-domain data to data and labels
X, y = D[:,:-1], D[:,-1]

# Split to train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# Separate OOD data
OOD = df[OOD_idx].values
OOD = scaler.transform(OOD)         # need to also transform it to be compatible with the NN.
X_OOD, y_OOD = OOD[:,:-1], OOD[:,-1]

# Hyperparameters
n_features = X_train.shape[1]
n_classes = 1
n_hidden_1 = 100
n_hidden_2 = 30
network = [n_hidden_1, n_hidden_2]
activation = 'relu'
n_epochs = 10000
learning_rate = 0.0001
weight_decay = 1e-5
batch_size = 64

# Transformation required for regression problem
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)
y_OOD = y_OOD.reshape(-1, 1)

# Tensor datasets
train_dataset = data_loaders.create_torch_dataset(X_train, y_train, to_LongTensor=False)
test_dataset = data_loaders.create_torch_dataset(X_test, y_test, to_LongTensor=False)
OOD_dataset = data_loaders.create_torch_dataset(X_OOD, y_OOD, to_LongTensor=False)

# Data loaders on gpu
train_loader = data_loaders.create_loader(train_dataset, batch_size, device)
test_loader = data_loaders.create_loader(test_dataset, batch_size, device)
OOD_loader = data_loaders.create_loader(OOD_dataset, batch_size, device)

# %% [markdown]
# ### ReLU

# %%
model = MLP(n_features, 1, network, activation, batch_norm=True).to(device)
loss_function = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train
train_losses = fit_regr(model, loss_function, optimizer, train_loader, 
    n_epochs=n_epochs, verbose=0, early_stopping='dev', return_losses=True)
avg_train_loss = train_losses[-1]

print(f"Average Train MSE: {avg_train_loss:.5f}")  

plt.figure(figsize=(9,6))
plt.plot(train_losses)
plt.grid()
plt.xlabel("Epoch", fontsize=20)
plt.ylabel("Loss", fontsize=20)
plt.title("MSE loss", fontsize=20)
plt.show()

avg_test_loss = test_regr(model, loss_function, test_loader, return_loss=True)

print(f"Average test MSE = {avg_test_loss:.5f}")   

avg_OOD_loss = test_regr(model, loss_function, OOD_loader, return_loss=True)

print(f"Average OOD loss = {avg_OOD_loss:.10f}")  
print(f"Average OOD loss to train loss ratio: {avg_OOD_loss / avg_train_loss : .3f}")
print(f"Average OOD loss to test loss ratio: {avg_OOD_loss / avg_test_loss : .3f}")
# Out:
# Average Train MSE: 0.00005
# Average test MSE = 0.00006
# Average OOD loss = 0.0018302139
# Average OOD loss to train loss ratio:  35.159
# Average OOD loss to test loss ratio:  30.667

# %% [markdown]
# ### Abs

# %%
activation = 'abs'

# %%
model = MLP(n_features, 1, network, activation, batch_norm=True).to(device)
loss_function = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# %%
train_losses = fit_regr(model, loss_function, optimizer, train_loader, n_epochs=n_epochs,
                        verbose=2, early_stopping='dev', return_losses=True)
avg_train_loss = train_losses[-1]

print(f"Average Train MSE: {avg_train_loss:.5f}")
print(f"Total Train MSE: {len(X_train) * avg_train_loss:.5f}")

plt.figure(figsize=(9,6))
plt.plot(train_losses)
plt.grid()
plt.xlabel("Epoch", fontsize=20)
plt.ylabel("Loss", fontsize=20)
plt.title("MSE loss", fontsize=20)
plt.show()
# Out:
# Training: Epoch 1: Average MSE Loss: 0.00505026
# Training: Epoch 2: Average MSE Loss: 0.00356407
# Training: Epoch 3: Average MSE Loss: 0.00300067
# Training: Epoch 4: Average MSE Loss: 0.00258042
# Training: Epoch 5: Average MSE Loss: 0.00222892
# Training: Epoch 6: Average MSE Loss: 0.00191779
# Training: Epoch 7: Average MSE Loss: 0.00163474
# Training: Epoch 8: Average MSE Loss: 0.00137662
# Training: Epoch 9: Average MSE Loss: 0.00114295
# Training: Epoch 10: Average MSE Loss: 0.00093423
# Training: Epoch 11: Average MSE Loss: 0.00075096
# Training: Epoch 12: Average MSE Loss: 0.00059547
# Training: Epoch 13: Average MSE Loss: 0.00046838
# Training: Epoch 14: Average MSE Loss: 0.00036796
# Training: Epoch 15: Average MSE Loss: 0.00029160
# Training: Epoch 16: Average MSE Loss: 0.00023582
# Training: Epoch 17: Average MSE Loss: 0.00019640
# Training: Epoch 18: Average MSE Loss: 0.00016911
# Training: Epoch 19: Average MSE Loss: 0.00015034
# Training: Epoch 20: Average MSE Loss: 0.00013742
# Training: Epoch 21: Average MSE Loss: 0.00012835
# Training: Epoch 22: Average MSE Loss: 0.00012194
# Training: Epoch 23: Average MSE Loss: 0.00011700
# Training: Epoch 24: Average MSE Loss: 0.00011296
# Training: Epoch 25: Average MSE Loss: 0.00010960
# Training: Epoch 26: Average MSE Loss: 0.00010662
# Training: Epoch 27: Average MSE Loss: 0.00010415
# Training: Epoch 28: Average MSE Loss: 0.00010178
# Training: Epoch 29: Average MSE Loss: 0.00009963
# Training: Epoch 30: Average MSE Loss: 0.00009759
# Training: Epoch 31: Average MSE Loss: 0.00009585
# Training: Epoch 32: Average MSE Loss: 0.00009412
# Training: Epoch 33: Average MSE Loss: 0.00009246
# Training: Epoch 34: Average MSE Loss: 0.00009090
# Training: Epoch 35: Average MSE Loss: 0.00008952
# Training: Epoch 36: Average MSE Loss: 0.00008823
# Training: Epoch 37: Average MSE Loss: 0.00008696
# Training: Epoch 38: Average MSE Loss: 0.00008568
# Training: Epoch 39: Average MSE Loss: 0.00008447
# Training: Epoch 40: Average MSE Loss: 0.00008337
# Training: Epoch 41: Average MSE Loss: 0.00008219
# Training: Epoch 42: Average MSE Loss: 0.00008117
# Training: Epoch 43: Average MSE Loss: 0.00008014
# Training: Epoch 44: Average MSE Loss: 0.00007916
# Training: Epoch 45: Average MSE Loss: 0.00007816
# Training: Epoch 46: Average MSE Loss: 0.00007721
# Training: Epoch 47: Average MSE Loss: 0.00007635
# Training: Epoch 48: Average MSE Loss: 0.00007554
# Training: Epoch 49: Average MSE Loss: 0.00007475
# Training: Epoch 50: Average MSE Loss: 0.00007404
# Training: Epoch 51: Average MSE Loss: 0.00007333
# Training: Epoch 52: Average MSE Loss: 0.00007274
# Training: Epoch 53: Average MSE Loss: 0.00007203
# Training: Epoch 54: Average MSE Loss: 0.00007139
# Training: Epoch 55: Average MSE Loss: 0.00007077
# Training: Epoch 56: Average MSE Loss: 0.00007009
# Training: Epoch 57: Average MSE Loss: 0.00006950
# Training: Epoch 58: Average MSE Loss: 0.00006896
# Training: Epoch 59: Average MSE Loss: 0.00006840
# Training: Epoch 60: Average MSE Loss: 0.00006792
# Training: Epoch 61: Average MSE Loss: 0.00006742
# Training: Epoch 62: Average MSE Loss: 0.00006700
# Training: Epoch 63: Average MSE Loss: 0.00006658
# Training: Epoch 64: Average MSE Loss: 0.00006615
# Training: Epoch 65: Average MSE Loss: 0.00006579
# Training: Epoch 66: Average MSE Loss: 0.00006540
# Training: Epoch 67: Average MSE Loss: 0.00006504
# Training: Epoch 68: Average MSE Loss: 0.00006470
# Training: Epoch 69: Average MSE Loss: 0.00006435
# Training: Epoch 70: Average MSE Loss: 0.00006403
# Training: Epoch 71: Average MSE Loss: 0.00006370
# Training: Epoch 72: Average MSE Loss: 0.00006337
# Training: Epoch 73: Average MSE Loss: 0.00006307
# Training: Epoch 74: Average MSE Loss: 0.00006279
# Training: Epoch 75: Average MSE Loss: 0.00006253
# Training: Epoch 76: Average MSE Loss: 0.00006227
# Training: Epoch 77: Average MSE Loss: 0.00006202
# Training: Epoch 78: Average MSE Loss: 0.00006177
# Training: Epoch 79: Average MSE Loss: 0.00006150
# Training: Epoch 80: Average MSE Loss: 0.00006126
# Training: Epoch 81: Average MSE Loss: 0.00006102
# Training: Epoch 82: Average MSE Loss: 0.00006077
# Training: Epoch 83: Average MSE Loss: 0.00006058
# Training: Epoch 84: Average MSE Loss: 0.00006039
# Training: Epoch 85: Average MSE Loss: 0.00006019
# Training: Epoch 86: Average MSE Loss: 0.00005995
# Training: Epoch 87: Average MSE Loss: 0.00005976
# Training: Epoch 88: Average MSE Loss: 0.00005953
# Training: Epoch 89: Average MSE Loss: 0.00005934
# Training: Epoch 90: Average MSE Loss: 0.00005916
# Training: Epoch 91: Average MSE Loss: 0.00005897
# Training: Epoch 92: Average MSE Loss: 0.00005877
# Training: Epoch 93: Average MSE Loss: 0.00005859
# Training: Epoch 94: Average MSE Loss: 0.00005844
# Training: Epoch 95: Average MSE Loss: 0.00005824
# Training: Epoch 96: Average MSE Loss: 0.00005808
# Training: Epoch 97: Average MSE Loss: 0.00005790
# Training: Epoch 98: Average MSE Loss: 0.00005775
# Training: Epoch 99: Average MSE Loss: 0.00005759
# Training: Epoch 100: Average MSE Loss: 0.00005746
# Training: Epoch 101: Average MSE Loss: 0.00005729
# Training: Epoch 102: Average MSE Loss: 0.00005714
# Training: Epoch 103: Average MSE Loss: 0.00005699
# Training: Epoch 104: Average MSE Loss: 0.00005681
# Training: Epoch 105: Average MSE Loss: 0.00005666
# Training: Epoch 106: Average MSE Loss: 0.00005652
# Training: Epoch 107: Average MSE Loss: 0.00005637
# Training: Epoch 108: Average MSE Loss: 0.00005624
# Training: Epoch 109: Average MSE Loss: 0.00005610
# Training: Epoch 110: Average MSE Loss: 0.00005595
# Training: Epoch 111: Average MSE Loss: 0.00005582
# Training: Epoch 112: Average MSE Loss: 0.00005570
# Training: Epoch 113: Average MSE Loss: 0.00005558
# Training: Epoch 114: Average MSE Loss: 0.00005546
# Training: Epoch 115: Average MSE Loss: 0.00005537
# Training: Epoch 116: Average MSE Loss: 0.00005525
# Training: Epoch 117: Average MSE Loss: 0.00005516
# Training: Epoch 118: Average MSE Loss: 0.00005506
# Training: Epoch 119: Average MSE Loss: 0.00005496
# Training: Epoch 120: Average MSE Loss: 0.00005483
# Training: Epoch 121: Average MSE Loss: 0.00005475
# Training: Epoch 122: Average MSE Loss: 0.00005464
# Training: Epoch 123: Average MSE Loss: 0.00005455
# Training: Epoch 124: Average MSE Loss: 0.00005447
# Training: Epoch 125: Average MSE Loss: 0.00005436
# Training: Epoch 126: Average MSE Loss: 0.00005428
# Training: Epoch 127: Average MSE Loss: 0.00005420
# Training: Epoch 128: Average MSE Loss: 0.00005407
# Training: Epoch 129: Average MSE Loss: 0.00005400
# Training: Epoch 130: Average MSE Loss: 0.00005388
# Training: Epoch 131: Average MSE Loss: 0.00005378
# Training: Epoch 132: Average MSE Loss: 0.00005372
# Training: Epoch 133: Average MSE Loss: 0.00005360
# Training: Epoch 134: Average MSE Loss: 0.00005353
# Training: Epoch 135: Average MSE Loss: 0.00005343
# Training: Epoch 136: Average MSE Loss: 0.00005337
# Training: Epoch 137: Average MSE Loss: 0.00005327
# Training: Epoch 138: Average MSE Loss: 0.00005319
# Training: Epoch 139: Average MSE Loss: 0.00005312
# Training: Epoch 140: Average MSE Loss: 0.00005303
# Training: Epoch 141: Average MSE Loss: 0.00005296
# Training: Epoch 142: Average MSE Loss: 0.00005288
# Training: Epoch 143: Average MSE Loss: 0.00005281
# Training: Epoch 144: Average MSE Loss: 0.00005271
# Training: Epoch 145: Average MSE Loss: 0.00005265
# Training: Epoch 146: Average MSE Loss: 0.00005256
# Training: Epoch 147: Average MSE Loss: 0.00005250
# Training: Epoch 148: Average MSE Loss: 0.00005243
# Training: Epoch 149: Average MSE Loss: 0.00005234
# Training: Epoch 150: Average MSE Loss: 0.00005229
# Training: Epoch 151: Average MSE Loss: 0.00005221
# Training: Epoch 152: Average MSE Loss: 0.00005216
# Training: Epoch 153: Average MSE Loss: 0.00005211
# Training: Epoch 154: Average MSE Loss: 0.00005202
# Training: Epoch 155: Average MSE Loss: 0.00005198
# Training: Epoch 156: Average MSE Loss: 0.00005189
# Training: Epoch 157: Average MSE Loss: 0.00005182
# Training: Epoch 158: Average MSE Loss: 0.00005179
# Training: Epoch 159: Average MSE Loss: 0.00005171
# Training: Epoch 160: Average MSE Loss: 0.00005165
# Training: Epoch 161: Average MSE Loss: 0.00005160
# Training: Epoch 162: Average MSE Loss: 0.00005153
# Training: Epoch 163: Average MSE Loss: 0.00005147
# Training: Epoch 164: Average MSE Loss: 0.00005141
# Training: Epoch 165: Average MSE Loss: 0.00005134
# Training: Epoch 166: Average MSE Loss: 0.00005130
# Training: Epoch 167: Average MSE Loss: 0.00005124
# Training: Epoch 168: Average MSE Loss: 0.00005117
# Training: Epoch 169: Average MSE Loss: 0.00005112
# Training: Epoch 170: Average MSE Loss: 0.00005106
# Training: Epoch 171: Average MSE Loss: 0.00005101
# Training: Epoch 172: Average MSE Loss: 0.00005096
# Training: Epoch 173: Average MSE Loss: 0.00005090
# Training: Epoch 174: Average MSE Loss: 0.00005085
# Training: Epoch 175: Average MSE Loss: 0.00005081
# Training: Epoch 176: Average MSE Loss: 0.00005073
# Training: Epoch 177: Average MSE Loss: 0.00005071
# Training: Epoch 178: Average MSE Loss: 0.00005065
# Training: Epoch 179: Average MSE Loss: 0.00005061
# Training: Epoch 180: Average MSE Loss: 0.00005056
# Training: Epoch 181: Average MSE Loss: 0.00005050
# Training: Epoch 182: Average MSE Loss: 0.00005047
# Training: Epoch 183: Average MSE Loss: 0.00005042
# Training: Epoch 184: Average MSE Loss: 0.00005039
# Training: Epoch 185: Average MSE Loss: 0.00005033
# Training: Epoch 186: Average MSE Loss: 0.00005029
# Training: Epoch 187: Average MSE Loss: 0.00005025
# Training: Epoch 188: Average MSE Loss: 0.00005021
# Training: Epoch 189: Average MSE Loss: 0.00005016
# Training: Epoch 190: Average MSE Loss: 0.00005014
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 train_losses = fit_regr(model, loss_function, optimizer, train_loader, n_epochs=n_epochs,
#       2                         verbose=2, early_stopping='dev', return_losses=True)
#       3 avg_train_loss = train_losses[-1]
#       5 print(f"Average Train MSE: {avg_train_loss:.5f}")
#
# File ~\Documents\Alex\Master\Internship\github\InternshipMatakos\src\train_test.py:41, in fit_regr(model, loss_func, optimizer, loader, n_epochs, verbose, early_stopping, return_losses)
#      39 loss_epoch = 0
#      40 total = 0
# ---> 41 for batch_num, (data, target) in enumerate(loader):
#      43     model.zero_grad()
#      44     output = model(data)
#
# File ~\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py:570, in _SingleProcessDataLoaderIter._next_data(self)
#     568 def _next_data(self):
#     569     index = self._next_index()  # may raise StopIteration
# --> 570     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571     if self._pin_memory:
#     572         data = _utils.pin_memory.pin_memory(data)
#
# File ~\anaconda3\envs\torch\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 else:
#      51     data = self.dataset[possibly_batched_index]
# ---> 52 return self.collate_fn(data)
#
# File ~\anaconda3\envs\torch\lib\site-packages\torch\utils\data\_utils\collate.py:172, in default_collate(batch)
#     169 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     171 if isinstance(elem, tuple):
# --> 172     return [default_collate(samples) for samples in transposed]  # Backwards compatibility.
#     173 else:
#     174     try:
#
# File ~\anaconda3\envs\torch\lib\site-packages\torch\utils\data\_utils\collate.py:172, in <listcomp>(.0)
#     169 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     171 if isinstance(elem, tuple):
# --> 172     return [default_collate(samples) for samples in transposed]  # Backwards compatibility.
#     173 else:
#     174     try:
#
# File ~\anaconda3\envs\torch\lib\site-packages\torch\utils\data\_utils\collate.py:138, in default_collate(batch)
#     136         storage = elem.storage()._new_shared(numel)
#     137         out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 138     return torch.stack(batch, 0, out=out)
#     139 elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#     140         and elem_type.__name__ != 'string_':
#     141     if elem_type.__name__ == 'ndarray' or elem_type.__name__ == 'memmap':
#     142         # array of string classes and object
#
# KeyboardInterrupt:

# %%
avg_test_loss = test_regr(model, loss_function, test_loader, return_loss=True)

print(f"Average test MSE = {avg_test_loss:.5f}")   
print(f"Total test MSE: {len(X_test) * avg_train_loss:.5f}")
# Out:
# Average test MSE = 0.00007
# Total test MSE: 0.07965

# %%
avg_OOD_loss = test_regr(model, loss_function, OOD_loader, return_loss=True)

print(f"Average OOD loss = {avg_OOD_loss:.10f}")  
print(f"Average OOD loss to train loss ratio: {avg_OOD_loss / avg_train_loss : .3f}")
print(f"Average OOD loss to test loss ratio: {avg_OOD_loss / avg_test_loss : .3f}")
# Out:
# Average OOD loss = 0.0018426714
# Average OOD loss to train loss ratio:  35.398
# Average OOD loss to test loss ratio:  27.314

# %%
def pipeline(X_train, X_test, y_train, y_test, verbose=0):
    
    # Transformation required for regression problem
    y_train = y_train.reshape(-1, 1)
    y_test = y_test.reshape(-1, 1)

    # Tensor datasets
    train_dataset = data_loaders.create_torch_dataset(X_train, y_train, to_LongTensor=False)
    test_dataset = data_loaders.create_torch_dataset(X_test, y_test, to_LongTensor=False)

    # Data loaders on gpu
    train_loader = data_loaders.create_loader(train_dataset, batch_size, device)
    test_loader = data_loaders.create_loader(test_dataset, batch_size, device)

    # Model setup
    model = MLP(n_features, 1, network, activation).to(device)

    loss_function = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    # fit function optionally returns a list with the epoch-wise losses
    train_loss = fit_regr(model, loss_function, optimizer, train_loader, 
                 n_epochs=n_epochs, verbose=1, early_stopping=True, return_losses=True) 
    test_loss = test_regr(model, loss_function, test_loader, verbose=0, return_loss=True) 
    
    if verbose:
        print(f"Average Train MSE Loss: {train_loss[-1] : .10f}")
        print(f"Average Test MSE Loss : {test_loss : .10f}" )

    return train_loss, test_loss                 # train loss is a list, test loss is a float

# %%
n_splits = 10
kf = KFold(n_splits)

train_losses = np.zeros(n_splits)
test_losses = np.zeros(n_splits)
train_losses_plot = []                           # for plotting loss curves
for i, (train_index, test_index) in enumerate(kf.split(X)):
    
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    print("\nTraining on fold no. %d" %(i+1))
    epoch_wise_train_losses, test_losses[i] = pipeline(X_train, X_test, y_train, y_test, verbose=1)
    train_losses[i] = epoch_wise_train_losses[-1]
    train_losses_plot.append(epoch_wise_train_losses)
    
print("\nTrain losses:", train_losses)
print("\nTest losses:", test_losses)

avg_train_loss_k_folds = train_losses.mean() 
avg_test_loss_k_folds = test_losses.mean() 
print(f"\nAvg train loss over all folds: {avg_train_loss_k_folds :.5f}")
print(f"Avg total train loss over all folds: {len(X_train) * avg_train_loss_k_folds :.5f}")
print(f"\nAvg test loss over all folds: {avg_test_loss_k_folds :.5f}")
print(f"Avg total test loss over all folds: {len(X_test) * avg_test_loss_k_folds :.5f}")

plt.figure(figsize=(9,6))
for losses in train_losses_plot:
    plt.plot(losses)
plt.grid()
plt.xlabel("Epoch", fontsize=20)
plt.ylabel("Loss", fontsize=20)
plt.title(f"Loss curves for {n_splits} folds", fontsize=20)
plt.show()
# Out:
# Training on fold no. 1
# Loss has stopped decreasing after epoch 152 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001394783
# Average Test MSE Loss :  0.0032228815
#
# Training on fold no. 2
# Loss has stopped decreasing after epoch 179 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001291957
# Average Test MSE Loss :  0.0037405792
#
# Training on fold no. 3
# Loss has stopped decreasing after epoch 169 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001569484
# Average Test MSE Loss :  0.0030567419
#
# Training on fold no. 4
# Loss has stopped decreasing after epoch 164 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001339548
# Average Test MSE Loss :  0.0009278679
#
# Training on fold no. 5
# Loss has stopped decreasing after epoch 145 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001395873
# Average Test MSE Loss :  0.0016236231
#
# Training on fold no. 6
# Loss has stopped decreasing after epoch 129 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001837365
# Average Test MSE Loss :  0.0031865031
#
# Training on fold no. 7
# Loss has stopped decreasing after epoch 163 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0002028137
# Average Test MSE Loss :  0.0041024383
#
# Training on fold no. 8
# Loss has stopped decreasing after epoch 159 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001743406
# Average Test MSE Loss :  0.0021123279
#
# Training on fold no. 9
# Loss has stopped decreasing after epoch 155 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001585881
# Average Test MSE Loss :  0.0010134519
#
# Training on fold no. 10
# Loss has stopped decreasing after epoch 173 (average of 50 epochs).
# STOPPING EARLY.
# Average Train MSE Loss:  0.0001899113
# Average Test MSE Loss :  0.0011044368
#
# Train losses: [0.00013948 0.0001292  0.00015695 0.00013395 0.00013959 0.00018374
#  0.00020281 0.00017434 0.00015859 0.00018991]
#
# Test losses: [0.00322288 0.00374058 0.00305674 0.00092787 0.00162362 0.0031865
#  0.00410244 0.00211233 0.00101345 0.00110444]
#
# Avg train loss over all folds: 0.00016
# Avg total train loss over all folds: 0.11935
#
# Avg test loss over all folds: 0.00241
# Avg total test loss over all folds: 0.19754
